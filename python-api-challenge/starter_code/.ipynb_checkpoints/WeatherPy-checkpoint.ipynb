# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 629

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "http://api.openweathermap.org/data/2.5/weather?"

# set up base url
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []
city_list = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = "output_data/cities.csv"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = url + "&q=" + city # YOUR CODE HERE
        response = requests.get(city_weather).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_list.append(response["name"])
        city_lat.append(response["coord"]["lat"]) # YOUR CODE HERE
        city_lng.append(response["coord"]["lon"])  # YOUR CODE HERE
        city_max_temp.append(response["main"]["temp_max"])  # YOUR CODE HERE
        city_humidity.append(response["main"]["humidity"])  # YOUR CODE HERE
        city_clouds.append(response["clouds"]["all"])  # YOUR CODE HERE
        city_wind.append(response["wind"]["speed"])  # YOUR CODE HERE
        city_country.append(response["sys"]["country"])  # YOUR CODE HERE
        city_date.append(response["dt"])  # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | bow island
# Processing Record 5 of Set 1 | gornopravdinsk
# Processing Record 6 of Set 1 | raudeberg
# Processing Record 7 of Set 1 | visby
# Processing Record 8 of Set 1 | broome
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | linxia
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | adre
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | joshimath
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | gorodovikovsk
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | udachnyy
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | sheopur
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | tual
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | jiangyou
# Processing Record 35 of Set 1 | abnub
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | ballina
# Processing Record 40 of Set 1 | sorong
# Processing Record 41 of Set 1 | goma
# Processing Record 42 of Set 1 | inuvik
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | arroyo
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | chunoyar
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | fortuna
# Processing Record 0 of Set 2 | elko
# Processing Record 1 of Set 2 | mykolayivka
# Processing Record 2 of Set 2 | asosa
# Processing Record 3 of Set 2 | itarema
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | labuhan
# Processing Record 8 of Set 2 | semey
# Processing Record 9 of Set 2 | zhigansk
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | padang
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | itacurubi del rosario
# Processing Record 15 of Set 2 | shingu
# Processing Record 16 of Set 2 | mahebourg
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 2 | toowoomba
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | plettenberg bay
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | roseto degli abruzzi
# Processing Record 25 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | oranjemund
# Processing Record 28 of Set 2 | rocha
# Processing Record 29 of Set 2 | puri
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | shumskiy
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | port hedland
# Processing Record 34 of Set 2 | margate
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | glubokiy
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | laguna
# Processing Record 40 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 41 of Set 2 | olinda
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | mlowo
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | ikom
# Processing Record 48 of Set 2 | xining
# Processing Record 49 of Set 2 | jijiga
# Processing Record 0 of Set 3 | westport
# Processing Record 1 of Set 3 | varna
# Processing Record 2 of Set 3 | sauk rapids
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | christchurch
# Processing Record 5 of Set 3 | dauphin
# Processing Record 6 of Set 3 | jalu
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | broken hill
# Processing Record 11 of Set 3 | richards bay
# Processing Record 12 of Set 3 | bontang
# Processing Record 13 of Set 3 | mirassol
# Processing Record 14 of Set 3 | college
# Processing Record 15 of Set 3 | trelew
# Processing Record 16 of Set 3 | fort nelson
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | djibo
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | anori
# Processing Record 21 of Set 3 | le port
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | gwembe
# Processing Record 25 of Set 3 | jerome
# Processing Record 26 of Set 3 | emba
# Processing Record 27 of Set 3 | lagoa
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | gamba
# Processing Record 32 of Set 3 | kapaa
# Processing Record 33 of Set 3 | iskandar
# Processing Record 34 of Set 3 | bluff
# Processing Record 35 of Set 3 | sabla
# Processing Record 36 of Set 3 | galveston
# Processing Record 37 of Set 3 | naze
# Processing Record 38 of Set 3 | palmer
# Processing Record 39 of Set 3 | makakilo city
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | bubaque
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | kjollefjord
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | koceljeva
# Processing Record 47 of Set 3 | vila velha
# Processing Record 48 of Set 3 | acajutla
# Processing Record 49 of Set 3 | makurdi
# Processing Record 0 of Set 4 | sambava
# Processing Record 1 of Set 4 | preston
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | north platte
# Processing Record 4 of Set 4 | quelimane
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | ust-charyshskaya pristan
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | kavaratti
# Processing Record 10 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | port lincoln
# Processing Record 13 of Set 4 | frontera
# Processing Record 14 of Set 4 | qaqortoq
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | ahipara
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | port hardy
# Processing Record 19 of Set 4 | qasigiannguit
# Processing Record 20 of Set 4 | mugur-aksy
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 23 of Set 4 | lithgow
# Processing Record 24 of Set 4 | storm lake
# Processing Record 25 of Set 4 | castro
# Processing Record 26 of Set 4 | san lawrenz
# Processing Record 27 of Set 4 | bereda
# Processing Record 28 of Set 4 | qaanaaq
# Processing Record 29 of Set 4 | axim
# Processing Record 30 of Set 4 | jaisalmer
# Processing Record 31 of Set 4 | pocoes
# Processing Record 32 of Set 4 | tazmalt
# Processing Record 33 of Set 4 | hargeysa
# Processing Record 34 of Set 4 | san ignacio
# Processing Record 35 of Set 4 | ca mau
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | divnomorskoye
# Processing Record 38 of Set 4 | pahrump
# Processing Record 39 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 4 | balao
# Processing Record 41 of Set 4 | meulaboh
# Processing Record 42 of Set 4 | umm lajj
# Processing Record 43 of Set 4 | tuktoyaktuk
# Processing Record 44 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 4 | henties bay
# Processing Record 46 of Set 4 | port-cartier
# Processing Record 47 of Set 4 | lago da pedra
# Processing Record 48 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 0 of Set 5 | hirado
# Processing Record 1 of Set 5 | sandpoint
# Processing Record 2 of Set 5 | fleetwood
# Processing Record 3 of Set 5 | lebanon
# Processing Record 4 of Set 5 | neuquen
# Processing Record 5 of Set 5 | huntsville
# Processing Record 6 of Set 5 | tutoia
# Processing Record 7 of Set 5 | ust-nera
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | ostersund
# Processing Record 11 of Set 5 | kamenka
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 5 | siirt
# Processing Record 15 of Set 5 | namibe
# Processing Record 16 of Set 5 | vanavara
# Processing Record 17 of Set 5 | francavilla al mare
# Processing Record 18 of Set 5 | kastamonu
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | damghan
# Processing Record 22 of Set 5 | cherskiy
# Processing Record 23 of Set 5 | riachao das neves
# Processing Record 24 of Set 5 | merauke
# Processing Record 25 of Set 5 | griffith
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | bairiki
# Processing Record 28 of Set 5 | maldonado
# Processing Record 29 of Set 5 | waipawa
# Processing Record 30 of Set 5 | komsomolskiy
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | ocampo
# Processing Record 33 of Set 5 | frankfort
# Processing Record 34 of Set 5 | senanga
# Processing Record 35 of Set 5 | belozerskoye
# Processing Record 36 of Set 5 | gambela
# Processing Record 37 of Set 5 | salalah
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | almaznyy
# Processing Record 40 of Set 5 | beira
# Processing Record 41 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 5 | santa helena
# Processing Record 43 of Set 5 | roald
# Processing Record 44 of Set 5 | charters towers
# Processing Record 45 of Set 5 | iquitos
# Processing Record 46 of Set 5 | healdsburg
# Processing Record 47 of Set 5 | isangel
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | sitka
# Processing Record 0 of Set 6 | stornoway
# Processing Record 1 of Set 6 | general roca
# Processing Record 2 of Set 6 | salinas
# Processing Record 3 of Set 6 | woodward
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | leningradskiy
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | uzumlu
# City not found. Skipping...
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | antofagasta
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | concordia
# Processing Record 13 of Set 6 | mirnyy
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | darhan
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | salinopolis
# Processing Record 18 of Set 6 | nhulunbuy
# Processing Record 19 of Set 6 | koumac
# Processing Record 20 of Set 6 | kinsale
# Processing Record 21 of Set 6 | shimoda
# Processing Record 22 of Set 6 | dingle
# Processing Record 23 of Set 6 | gubkinskiy
# Processing Record 24 of Set 6 | norman wells
# Processing Record 25 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 6 | saint-francois
# Processing Record 27 of Set 6 | sao filipe
# Processing Record 28 of Set 6 | cumana
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | nuuk
# Processing Record 31 of Set 6 | srednekolymsk
# Processing Record 32 of Set 6 | pangnirtung
# Processing Record 33 of Set 6 | vila franca do campo
# Processing Record 34 of Set 6 | terney
# Processing Record 35 of Set 6 | cairns
# Processing Record 36 of Set 6 | alcudia
# Processing Record 37 of Set 6 | florianopolis
# Processing Record 38 of Set 6 | bambous virieux
# Processing Record 39 of Set 6 | langsa
# Processing Record 40 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 6 | machico
# Processing Record 42 of Set 6 | churapcha
# Processing Record 43 of Set 6 | mount isa
# Processing Record 44 of Set 6 | sept-iles
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | san-pedro
# Processing Record 47 of Set 6 | venado tuerto
# Processing Record 48 of Set 6 | hamadan
# Processing Record 49 of Set 6 | waingapu
# Processing Record 0 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | zyryanka
# Processing Record 2 of Set 7 | nemuro
# Processing Record 3 of Set 7 | sur
# Processing Record 4 of Set 7 | pangoa
# Processing Record 5 of Set 7 | rio grande
# Processing Record 6 of Set 7 | little current
# Processing Record 7 of Set 7 | manokwari
# Processing Record 8 of Set 7 | ambilobe
# Processing Record 9 of Set 7 | andenes
# Processing Record 10 of Set 7 | tumen
# Processing Record 11 of Set 7 | flinders
# Processing Record 12 of Set 7 | tromso
# Processing Record 13 of Set 7 | san andres
# Processing Record 14 of Set 7 | pathein
# Processing Record 15 of Set 7 | logan lake
# Processing Record 16 of Set 7 | alofi
# Processing Record 17 of Set 7 | iqaluit
# Processing Record 18 of Set 7 | suzhou
# Processing Record 19 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 20 of Set 7 | yermakovskoye
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | sompeta
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 7 | saint-leu
# Processing Record 26 of Set 7 | kodinsk
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | hobyo
# Processing Record 30 of Set 7 | mitchell
# Processing Record 31 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 7 | brainerd
# Processing Record 33 of Set 7 | rio duque
# Processing Record 34 of Set 7 | ishigaki
# Processing Record 35 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 7 | murchison
# Processing Record 37 of Set 7 | saint anthony
# Processing Record 38 of Set 7 | oyama
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | caravelas
# Processing Record 41 of Set 7 | pietarsaari
# Processing Record 42 of Set 7 | raigarh
# Processing Record 43 of Set 7 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 44 of Set 7 | barranca
# Processing Record 45 of Set 7 | kajaani
# Processing Record 46 of Set 7 | abrau-dyurso
# Processing Record 47 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 48 of Set 7 | krasnovishersk
# Processing Record 49 of Set 7 | northam
# Processing Record 0 of Set 8 | valparaiso
# Processing Record 1 of Set 8 | jimo
# Processing Record 2 of Set 8 | jodar
# Processing Record 3 of Set 8 | misratah
# Processing Record 4 of Set 8 | mayo
# Processing Record 5 of Set 8 | ankazoabo
# Processing Record 6 of Set 8 | havoysund
# Processing Record 7 of Set 8 | kayerkan
# Processing Record 8 of Set 8 | watertown
# Processing Record 9 of Set 8 | pocatello
# Processing Record 10 of Set 8 | avera
# Processing Record 11 of Set 8 | dudinka
# Processing Record 12 of Set 8 | hunchun
# Processing Record 13 of Set 8 | cervo
# Processing Record 14 of Set 8 | nizhniy kuranakh
# Processing Record 15 of Set 8 | aksha
# Processing Record 16 of Set 8 | magistralnyy
# Processing Record 17 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 8 | daru
# Processing Record 19 of Set 8 | kenai
# Processing Record 20 of Set 8 | namatanai
# Processing Record 21 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 22 of Set 8 | ambulu
# Processing Record 23 of Set 8 | kruisfontein
# Processing Record 24 of Set 8 | teocuitatlan de corona
# Processing Record 25 of Set 8 | buala
# Processing Record 26 of Set 8 | goderich
# Processing Record 27 of Set 8 | nizhneudinsk
# Processing Record 28 of Set 8 | kudat
# Processing Record 29 of Set 8 | mecca
# Processing Record 30 of Set 8 | porto belo
# Processing Record 31 of Set 8 | diapaga
# Processing Record 32 of Set 8 | djenne
# Processing Record 33 of Set 8 | half moon bay
# Processing Record 34 of Set 8 | teguldet
# Processing Record 35 of Set 8 | tumkur
# Processing Record 36 of Set 8 | ostroh
# Processing Record 37 of Set 8 | brae
# Processing Record 38 of Set 8 | yazman
# Processing Record 39 of Set 8 | piranshahr
# Processing Record 40 of Set 8 | gerede
# Processing Record 41 of Set 8 | yining
# Processing Record 42 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 8 | demyansk
# Processing Record 44 of Set 8 | tunxi
# City not found. Skipping...
# Processing Record 45 of Set 8 | bajos de haina
# Processing Record 46 of Set 8 | narnaul
# Processing Record 47 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 8 | harper
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 0 of Set 9 | edson
# Processing Record 1 of Set 9 | las margaritas
# Processing Record 2 of Set 9 | impfondo
# Processing Record 3 of Set 9 | bonavista
# Processing Record 4 of Set 9 | port augusta
# Processing Record 5 of Set 9 | vichayal
# City not found. Skipping...
# Processing Record 6 of Set 9 | seymchan
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | yinchuan
# Processing Record 9 of Set 9 | nome
# Processing Record 10 of Set 9 | sayyan
# Processing Record 11 of Set 9 | pisco
# Processing Record 12 of Set 9 | mandurah
# Processing Record 13 of Set 9 | changli
# Processing Record 14 of Set 9 | youkounkoun
# Processing Record 15 of Set 9 | morwell
# Processing Record 16 of Set 9 | atasu
# Processing Record 17 of Set 9 | san juan
# Processing Record 18 of Set 9 | pedernales
# Processing Record 19 of Set 9 | netanya
# Processing Record 20 of Set 9 | toamasina
# Processing Record 21 of Set 9 | kamphaeng phet
# Processing Record 22 of Set 9 | tulum
# Processing Record 23 of Set 9 | aquin
# Processing Record 24 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 9 | duldurga
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | kiunga
# Processing Record 28 of Set 9 | susangerd
# Processing Record 29 of Set 9 | teahupoo
# Processing Record 30 of Set 9 | korla
# Processing Record 31 of Set 9 | erzin
# Processing Record 32 of Set 9 | pangkalanbuun
# Processing Record 33 of Set 9 | saryg-sep
# Processing Record 34 of Set 9 | loukhi
# Processing Record 35 of Set 9 | mahajanga
# Processing Record 36 of Set 9 | izumo
# Processing Record 37 of Set 9 | mao
# Processing Record 38 of Set 9 | hofn
# Processing Record 39 of Set 9 | mordovo
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | kochevo
# Processing Record 42 of Set 9 | beidao
# Processing Record 43 of Set 9 | kununurra
# Processing Record 44 of Set 9 | arona
# Processing Record 45 of Set 9 | jining
# Processing Record 46 of Set 9 | verkhnyaya inta
# Processing Record 47 of Set 9 | gat
# Processing Record 48 of Set 9 | poya
# Processing Record 49 of Set 9 | anloga
# Processing Record 0 of Set 10 | saint-louis
# Processing Record 1 of Set 10 | aklavik
# Processing Record 2 of Set 10 | tautira
# Processing Record 3 of Set 10 | morristown
# Processing Record 4 of Set 10 | kokopo
# Processing Record 5 of Set 10 | epe
# Processing Record 6 of Set 10 | shelburne
# Processing Record 7 of Set 10 | peace river
# Processing Record 8 of Set 10 | wajir
# Processing Record 9 of Set 10 | novyy urengoy
# Processing Record 10 of Set 10 | beyneu
# Processing Record 11 of Set 10 | tongzhou
# Processing Record 12 of Set 10 | kongoussi
# Processing Record 13 of Set 10 | geraldton
# Processing Record 14 of Set 10 | pribelskiy
# City not found. Skipping...
# Processing Record 15 of Set 10 | mennecy
# Processing Record 16 of Set 10 | faya
# Processing Record 17 of Set 10 | ust-kan
# Processing Record 18 of Set 10 | tanete
# Processing Record 19 of Set 10 | shakiso
# Processing Record 20 of Set 10 | yermolayevo
# Processing Record 21 of Set 10 | adigeni
# Processing Record 22 of Set 10 | sola
# Processing Record 23 of Set 10 | fuerte olimpo
# Processing Record 24 of Set 10 | karratha
# Processing Record 25 of Set 10 | bad windsheim
# Processing Record 26 of Set 10 | forbes
# Processing Record 27 of Set 10 | mingguang
# Processing Record 28 of Set 10 | codrington
# Processing Record 29 of Set 10 | olafsvik
# Processing Record 30 of Set 10 | guerrero negro
# Processing Record 31 of Set 10 | sorland
# Processing Record 32 of Set 10 | klaebu
# Processing Record 33 of Set 10 | hailar
# Processing Record 34 of Set 10 | tura
# Processing Record 35 of Set 10 | yulara
# Processing Record 36 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 37 of Set 10 | dondo
# Processing Record 38 of Set 10 | madimba
# Processing Record 39 of Set 10 | metz
# Processing Record 40 of Set 10 | itoman
# Processing Record 41 of Set 10 | wanaka
# Processing Record 42 of Set 10 | berbera
# Processing Record 43 of Set 10 | camargo
# Processing Record 44 of Set 10 | vostok
# Processing Record 45 of Set 10 | tripoli
# Processing Record 46 of Set 10 | sibolga
# Processing Record 47 of Set 10 | ixtapa
# Processing Record 48 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 10 | saint-georges
# Processing Record 0 of Set 11 | roseburg
# Processing Record 1 of Set 11 | uarini
# Processing Record 2 of Set 11 | port-gentil
# Processing Record 3 of Set 11 | ostrovnoy
# Processing Record 4 of Set 11 | walvis bay
# Processing Record 5 of Set 11 | bouar
# Processing Record 6 of Set 11 | san onofre
# Processing Record 7 of Set 11 | pozo colorado
# Processing Record 8 of Set 11 | camacha
# Processing Record 9 of Set 11 | south river
# Processing Record 10 of Set 11 | chekhov
# Processing Record 11 of Set 11 | kissidougou
# Processing Record 12 of Set 11 | natal
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | miri
# Processing Record 15 of Set 11 | laiwu
# Processing Record 16 of Set 11 | blagoyevo
# Processing Record 17 of Set 11 | yar-sale
# Processing Record 18 of Set 11 | ingham
# Processing Record 19 of Set 11 | novo aripuana
# Processing Record 20 of Set 11 | pevek
# Processing Record 21 of Set 11 | igrim
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | itapaci
# Processing Record 24 of Set 11 | bulawayo
# Processing Record 25 of Set 11 | mochudi
# Processing Record 26 of Set 11 | maryborough
# Processing Record 27 of Set 11 | mafinga
# Processing Record 28 of Set 11 | berdigestyakh
# Processing Record 29 of Set 11 | zharkent
# Processing Record 30 of Set 11 | evensk
# Processing Record 31 of Set 11 | zurrieq
# Processing Record 32 of Set 11 | nedjo
# Processing Record 33 of Set 11 | kieta
# Processing Record 34 of Set 11 | bukama
# Processing Record 35 of Set 11 | mikhaylovskoye
# Processing Record 36 of Set 11 | mabaruma
# Processing Record 37 of Set 11 | shetpe
# Processing Record 38 of Set 11 | lata
# Processing Record 39 of Set 11 | constitucion
# Processing Record 40 of Set 11 | crab hill
# City not found. Skipping...
# Processing Record 41 of Set 11 | luderitz
# Processing Record 42 of Set 11 | brun
# Processing Record 43 of Set 11 | raga
# Processing Record 44 of Set 11 | duayaw nkwanta
# Processing Record 45 of Set 11 | muzhi
# Processing Record 46 of Set 11 | high level
# Processing Record 47 of Set 11 | binucayan
# Processing Record 48 of Set 11 | quatre cocos
# Processing Record 49 of Set 11 | ulcinj
# Processing Record 0 of Set 12 | karabulak
# Processing Record 1 of Set 12 | sovetskiy
# Processing Record 2 of Set 12 | mwinilunga
# Processing Record 3 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 12 | matamoros
# Processing Record 5 of Set 12 | ermelo
# Processing Record 6 of Set 12 | bilibino
# Processing Record 7 of Set 12 | kismayo
# Processing Record 8 of Set 12 | chincha alta
# Processing Record 9 of Set 12 | vondrozo
# Processing Record 10 of Set 12 | kandrian
# Processing Record 11 of Set 12 | kuryk
# Processing Record 12 of Set 12 | usolye
# Processing Record 13 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 12 | koforidua
# Processing Record 15 of Set 12 | katsuura
# Processing Record 16 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 12 | necochea
# Processing Record 18 of Set 12 | takoradi
# Processing Record 19 of Set 12 | batemans bay
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | vallenar
# Processing Record 22 of Set 12 | zhezkazgan
# Processing Record 23 of Set 12 | santa maria del rio
# Processing Record 24 of Set 12 | nosy varika
# Processing Record 25 of Set 12 | santa cruz del sur
# Processing Record 26 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 12 | vanimo
# Processing Record 28 of Set 12 | russell
# Processing Record 29 of Set 12 | gizo
# Processing Record 30 of Set 12 | tuatapere
# Processing Record 31 of Set 12 | hamilton
# Processing Record 32 of Set 12 | la ronge
# Processing Record 33 of Set 12 | nampula
# Processing Record 34 of Set 12 | beloha
# Processing Record 35 of Set 12 | kralendijk
# Processing Record 36 of Set 12 | mbuji-mayi
# Processing Record 37 of Set 12 | abancay
# Processing Record 38 of Set 12 | akdepe
# Processing Record 39 of Set 12 | viedma
# Processing Record 40 of Set 12 | shakawe
# Processing Record 41 of Set 12 | ilhabela
# Processing Record 42 of Set 12 | baiyin
# Processing Record 43 of Set 12 | jizan
# Processing Record 44 of Set 12 | kaeo
# Processing Record 45 of Set 12 | mporokoso
# Processing Record 46 of Set 12 | san quintin
# Processing Record 47 of Set 12 | curuguaty
# Processing Record 48 of Set 12 | tete
# Processing Record 49 of Set 12 | linhares
# Processing Record 0 of Set 13 | aswan
# Processing Record 1 of Set 13 | ban nahin
# Processing Record 2 of Set 13 | saint andrews
# Processing Record 3 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 4 of Set 13 | santa isabel do rio negro
# Processing Record 5 of Set 13 | hambantota
# Processing Record 6 of Set 13 | poum
# Processing Record 7 of Set 13 | sosua
# Processing Record 8 of Set 13 | ketchikan
# Processing Record 9 of Set 13 | chapais
# Processing Record 10 of Set 13 | mont-dore
# Processing Record 11 of Set 13 | nalut
# Processing Record 12 of Set 13 | monrovia
# Processing Record 13 of Set 13 | porto walter
# Processing Record 14 of Set 13 | bull savanna
# Processing Record 15 of Set 13 | kungurtug
# Processing Record 16 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 13 | sitio novo do tocantins
# Processing Record 18 of Set 13 | grants
# Processing Record 19 of Set 13 | kristinehamn
# Processing Record 20 of Set 13 | egvekinot
# Processing Record 21 of Set 13 | taltal
# Processing Record 22 of Set 13 | port shepstone
# Processing Record 23 of Set 13 | inhambane
# Processing Record 24 of Set 13 | ust-koksa
# Processing Record 25 of Set 13 | boyolangu
# Processing Record 26 of Set 13 | catamarca
# Processing Record 27 of Set 13 | banda aceh
# Processing Record 28 of Set 13 | tsiroanomandidy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({
    "City": city_list,
    "Lat": city_lat,
    "Lng": city_lng,
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind Speed": city_wind,
    "Country": city_country,
    "Date": city_date
})

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df
# Out:
#                                     City      Lat       Lng  Max Temp  \
# 0                                 Barrow  71.2906 -156.7887    -18.69
# 1                        Arraial do Cabo -22.9661  -42.0278     74.75
# 2                           Longyearbyen  78.2186   15.6401     22.84
# 3                             Bow Island  49.8668 -111.3684     27.79
# 4                         Gornopravdinsk  60.0500   69.9000     12.76
# ..                                   ...      ...       ...       ...
# 576                           Ust'-Koksa  50.2696   85.6108      2.91
# 577                            Boyolangu  -8.1181  111.8935     84.11
# 578  San Fernando del Valle de Catamarca -28.4696  -65.7852     81.77
# 579                           Banda Aceh   5.5577   95.3222     83.91
# 580                      Tsiroanomandidy -18.7667   46.0333     67.50
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 0          98          56       15.50      US  1674622806
# 1          91         100       10.87      BR  1674622857
# 2          68          40       18.41      SJ  1674622858
# 3          76          88        8.68      CA  1674622815
# 4          94          99       10.04      RU  1674622859
# ..        ...         ...         ...     ...         ...
# 576        89         100        1.52      RU  1674623117
# 577        73          81        4.76      ID  1674623118
# 578        58          45        3.00      AR  1674623118
# 579        66          90        8.84      ID  1674623119
# 580        94         100       13.80      MG  1674623119
#
# [581 rows x 9 columns]

# %%
city_data_df.describe()
# Out:
#               Lat         Lng   Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  581.000000  581.000000  581.00000  581.000000  581.000000  581.000000
# mean    18.912268   19.169454   49.28315   73.161790   59.074010    8.034458
# std     33.973678   90.542260   31.21574   22.293605   39.205907    6.995468
# min    -54.800000 -179.166700  -44.99000    1.000000    0.000000    0.000000
# 25%    -10.750000  -61.644200   29.30000   63.000000   18.000000    3.240000
# 50%     22.075200   26.150000   59.14000   78.000000   74.000000    6.260000
# 75%     47.804300   97.968300   74.95000   91.000000  100.000000   10.870000
# max     78.218600  179.316700  100.54000  100.000000  100.000000   69.390000
#
#                Date
# count  5.810000e+02
# mean   1.674623e+09
# std    1.020171e+02
# min    1.674623e+09
# 25%    1.674623e+09
# 50%    1.674623e+09
# 75%    1.674623e+09
# max    1.674623e+09

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 Barrow  71.2906 -156.7887    -18.69        98          56
# 1        Arraial do Cabo -22.9661  -42.0278     74.75        91         100
# 2           Longyearbyen  78.2186   15.6401     22.84        68          40
# 3             Bow Island  49.8668 -111.3684     27.79        76          88
# 4         Gornopravdinsk  60.0500   69.9000     12.76        94          99
#
#          Wind Speed Country        Date
# City_ID
# 0             15.50      US  1674622806
# 1             10.87      BR  1674622857
# 2             18.41      SJ  1674622858
# 3              8.68      CA  1674622815
# 4             10.04      RU  1674622859

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor="blue", edgecolor="aqua")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Max Temp (01/24/23)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(alpha=0.25)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor="blue", edgecolor="aqua")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Humidity (01/24/23)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(alpha=0.25)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor="blue", edgecolor="aqua")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Cloudiness (01/24/23)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(alpha=0.25)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor="blue", edgecolor="aqua")

# Incorporate the other graph properties
# YOUR CODE HERE
plt.title("City Latitude vs. Wind Speed (01/24/23)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(alpha=0.25)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]
# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                Barrow  71.2906 -156.7887    -18.69        98          56
# 2          Longyearbyen  78.2186   15.6401     22.84        68          40
# 3            Bow Island  49.8668 -111.3684     27.79        76          88
# 4        Gornopravdinsk  60.0500   69.9000     12.76        94          99
# 5             Raudeberg  61.9875    5.1352     46.96         1         100
#
#          Wind Speed Country        Date
# City_ID
# 0             15.50      US  1674622806
# 2             18.41      SJ  1674622858
# 3              8.68      CA  1674622815
# 4             10.04      RU  1674622859
# 5             30.11      NO  1674622859

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]
# Display sample data
southern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        Arraial do Cabo -22.9661  -42.0278     74.75        91         100
# 10                Hobart -42.8794  147.3294     76.86        59          75
# 12            Bredasdorp -34.5322   20.0403     59.70        58           2
# 14          Punta Arenas -53.1500  -70.9167     51.91        50          75
# 16              Hermanus -34.4187   19.2345     54.81        63           9
#
#          Wind Speed Country        Date
# City_ID
# 1             10.87      BR  1674622857
# 10            10.36      AU  1674622862
# 12             1.34      ZA  1674622838
# 14            19.57      CL  1674622795
# 16             7.07      ZA  1674622865

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_vals = northern_hemi_df["Lat"]
y_vals = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("N. Hemisphere - Max Temp vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(0,0),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("Cities in the northern hemisphere moving farther from the equator, temperatures drop.")
print("This shows a strong negative correlation between latitude and tempuratures in the northern hemisphere.")
plt.savefig("nhem_temp_v_lat_plot.png")
# Out:
# The r-value is: 0.7033157286763161
# Cities in the northern hemisphere moving farther from the equator, temperatures drop.
# This shows a strong negative correlation between latitude and tempuratures in the northern hemisphere.

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_vals = southern_hemi_df["Lat"]
y_vals = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("S. Hemisphere - Max Temp vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.annotate(line_eq,(-55,93),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("Cities in the southern hemisphere moving closer to the equator, temperatures rise.")
print("This shows a slight positive correlation between latitude and temperature in the southern hemisphere.")
plt.savefig("shem_temp_v_lat_plot.png")
# Out:
# The r-value is: 0.1262501816845608
# Cities in the southern hemisphere moving closer to the equator, temperatures rise.
# This shows a slight positive correlation between latitude and temperature in the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_vals = northern_hemi_df["Lat"]
y_vals = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("N. Hemisphere - Humidity (%) vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a slight positive correlation between humidity and latitude for cities in the northern hemisphere.")

plt.savefig("nhem_humidity_v_lat_plot.png")
# Out:
# The r-value is: 0.14738807031928175
# There is a slight positive correlation between humidity and latitude for cities in the northern hemisphere.

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_vals = southern_hemi_df["Lat"]
y_vals = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("S. Hemisphere - Humidity (%) vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a slight correlation between humidity and latitude for cities in the southern hemisphere.")
plt.savefig("shem_humidity_v_lat_plot.png")
# Out:
# The r-value is: 0.22883209629977713
# There is a slight correlation between humidity and latitude for cities in the southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_vals = northern_hemi_df["Lat"]
y_vals = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("N. Hemisphere - Cloudiness (%) vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(50,10),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a positive correlation between cloudiness and latitude for cities in the northern hemisphere.")

plt.savefig("nhem_cloudiness_v_lat_plot.png")
# Out:
# The r-value is: 0.16015102248588645
# There is a positive correlation between cloudiness and latitude for cities in the northern hemisphere.

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_vals = southern_hemi_df["Lat"]
y_vals = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("S. Hemisphere - Cloudiness (%) vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(line_eq,(-50,45),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a correlation between cloudiness and latitude for cities in the southern hemisphere.")

plt.savefig("shem_cloudiness_v_lat_plot.png")
# Out:
# The r-value is: 0.24131392947021962
# There is a correlation between cloudiness and latitude for cities in the southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_vals = northern_hemi_df["Lat"]
y_vals = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("N. Hemisphere - Wind Speed (mph) vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(5,35),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a little correlation between wind speed and latitude for cities in the northern hemisphere.")

plt.savefig("nhem_wind_v_lat_plot.png")
# Out:
# The r-value is: 0.03060829140079046
# There is a little correlation between wind speed and latitude for cities in the northern hemisphere.

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_vals = southern_hemi_df["Lat"]
y_vals = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_vals, y_vals)
regress_vals = x_vals * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.scatter(x_vals,y_vals, facecolor="blue", edgecolor="aqua")
plt.plot(x_vals,regress_vals,"r-")
plt.title("S. Hemisphere - Wind Speed (mph)  vs. Latitude (01/24/23)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(line_eq,(-25,23),fontsize=15,color="red")

print(f"The r-value is: {rvalue**2}")
print("There is a slightly negative correlation between wind speed and latitude for cities in the southern hemisphere.")

plt.savefig("shem_wind_v_lat_plot.png")
# Out:
# The r-value is: 0.12304819571322617
# There is a slightly negative correlation between wind speed and latitude for cities in the southern hemisphere.
